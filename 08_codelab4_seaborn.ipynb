# %% [markdown]
# <a href="https://colab.research.google.com/github/cybermin/2021_PNUAC_AIData/blob/main/08_codelab4_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 시각화(data visualization)
# + 데이터 분석 결과를 쉽게 이해할 수 있도록 시각적으로 표현하고 전달되는 과정
# + 데이터 시각화를 통해 데이터에 내재된 트렌드, 이상치, 패턴등을 파악

# %% [markdown]
# 🏷️ **코랩 환경에서 한글 폰트 사용하기**
#
#
# ---

# %%
#한글 폰트 사용설치
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

#한글 폰트 추가
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

#그래프에서 마이너스 기호가 표시
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.title('한글')
plt.show()

# %% [markdown]
# 🏷️ **python 노트 : 경고무시**
#
#
# ---

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# &#9997; **pandas 노트 : 외부데이터 가져오기**
#
#
# ---
# + **외부 데이터 가져오기**
#   + csv 읽기
#     - 한글 파일명을 사용할 경우 : df = pd.read_csv(‘파일명‘, engine='python')
#     - 파일 내용 한글이 깨지는 경우 : df = pd.read_csv(‘파일명‘, engine='python', encoding='cp949')
#   >
#   ```
#   df = pd.read_csv(‘파일명‘)
#   ```
#
#   + 엑셀 읽기
#     - 한글 파일명을 사용할 경우 : df = pd.read_excel(‘파일명‘)
#   >
#   ```
#   df = pd.pd.read_excel(‘파일명‘)
#   ```
# ---

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/수업/pnuaiac/data/news.csv')
df.head()
# Out:
#    순위                                                 제목   댓글수     언론사  감성  신뢰도
# 0   1              전광훈 "젖비린내 이준석에 당하면 대한민국 끝나..민주·국힘 해산"  5618     뉴스1  부정    1
# 1   2           '건물 붕괴참사' 개입의혹 조폭출신 전 5·18단체 회장 해외도피(종합)  2265    연합뉴스  부정    1
# 2   3            이준석 접종 모습도 화제.. 상의 탈의하며 "국민에게 불쾌감 줘 민망"  1750    세계일보  부정    1
# 3   4               전광훈 "젖비린내 나는 이준석..민주·국민의힘 모두 해산 시켜야"  1649   아시아경제  부정    1
# 4   5  광복절부터 대체공휴일 된다는데.."결국 공무원만 좋은 일?" [이지효의 플러스 PICK]  1349  한국경제TV  부정    1

# %%
plt.plot(df['순위'], df['댓글수'])
plt.show()

# %%
df['댓글수'].plot()
plt.show()

# %% [markdown]
# # Seaborn
# + Matplotlib을 기반으로 다양한 색상 테마와 통계용 차트 등의 기능을 추가한 시각화 패키지
# + 기본적인 시각화 기능은 Matplotlib 패키지에 의존하며 통계 기능은 Statsmodels 패키지에 의존
# + 데이터프레임으로 다양한 통계 지표를 낼 수 있는 시각화 차트를 제공하기 때문에 데이터 분석에 활발히 사용되고 있는 패키지
# + 다차원 데이터 분석시 고려 사항
#   + 분석하고자 하는 데이터가 모두 실수 값인 경우
#   + 분석하고자 하는 데이터가 모두 카테고리 값인 경우
#   + 분석하고자 하는 데이터가 모두 실수 값과 카테고리 값이 섞여 있는 경우

# %%
import seaborn as sns

# %% [markdown]
# ## barplot
# + **카테고리 값에 따른 실수 값**의 평균과 편차를 표시하는 기본적인 바 차트를 생성
# + 평균은 막대의 높이로, 편차는 에러바(error bar)로 표시

# %%
df['언론사'].value_counts()
# Out:
# MBC       6
# JTBC      5
# 이데일리      3
# 세계일보      3
# 서울신문      3
# KBS       2
# 아시아경제     2
# 한겨레       2
# 연합뉴스      2
# 중앙일보      2
# 매일경제      2
# SBS       2
# 오마이뉴스     2
# 뉴스1       2
# 조선비즈      1
# MBN       1
# 국민일보      1
# 동아일보      1
# YTN       1
# 쿠키뉴스      1
# 문화일보      1
# 헤럴드경제     1
# 한국경제TV    1
# 뉴시스       1
# 노컷뉴스      1
# 한국일보      1
# Name: 언론사, dtype: int64

# %%
sns.barplot(x = '언론사', y='댓글수', data=df)
plt.xticks(rotation=90)
plt.title('언론사별 댓글수')
plt.show()

# %%
sns.barplot(x = '언론사', y='댓글수', hue='감성', data=df[:20])
plt.xticks(rotation=90)
plt.title('언론사별 댓글수')
plt.show()

# %% [markdown]
# ## histplot
# * **수치형(numerical) 데이터 분포**를 정확하게 표현해주는 그래픽

# %%
sns.histplot(x = '댓글수', data=df) 
plt.show()

# %%
sns.histplot(x = '댓글수', bins=5, data=df) 
plt.show()

# %% [markdown]
# ## distplot
# + 러그와 커널 밀도 표시 기능이 있어서 Matplotlib의 hist 명령보다 많이 사용
#   + 커널 밀도(kernel density): 커널이라는 함수를 겹치는 방법으로 히스토그램보다 부드러운 형태의 분포 곡선을 보여주는 방법
# + **수치형** 열을 인수

# %%
sns.distplot(df['댓글수'], kde = True) 
plt.show()

# %% [markdown]
# ## boxplot
# + 카테고리별 수치 데이터의 범위를 보여주고, 데이터분포와 ‘이상치’가 있는지 확인 가능
# + 구성
#   - 상자는 사분위 범위.
#   - 상자 가운데의 선은 중앙값(median)
#   - 맨 끝의 선은 1분위와 3분위
#   - 상자 바깥점은 이상치

# %%
sns.boxplot(x='감성', y='댓글수', data=df)
plt.title("감성별 댓글 분석")
plt.show()

# %% [markdown]
# ## count plot
# + 각 **카테고리 값**별로 데이터가 얼마나 있는지 표시

# %%
sns.countplot(x = '언론사', data=df)
plt.xticks(rotation=90)
plt.title('언론사별 뉴스수')
plt.show()

# %%
sns.countplot(x = '언론사', hue='감성', data=df)
plt.xticks(rotation=90)
plt.title('언론사별 뉴스수')
plt.show()

# %%
sns.countplot(x = '감성', data=df)
plt.title('감성 뉴스수')
plt.show()

# %% [markdown]
# &#9997; **Seborn 노트 : 수치값 표현**
#
#
# ---
# + ax.patches : ax가 가르키는 그래프에서, 막대들을 담고있는 리스트
# + p.get_bbox().bounds : 막대그래프의 정보를 나타냄.(p는 해당 막대)
#   + 왼쪽, 아래, 막대그래프의 폭, 높이에 대한 정보
# + ax.annotate(s, (x, y), ha=값) : 그래프 안에 특정 위치에 문자열
#   + ha : horizontal align
# ---

# %%
ax = sns.countplot(x = '감성', data=df)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate(height, (left+width/2, height*1.01), ha='center')
plt.show()

# %% [markdown]
# ## scatter plot
# + 두 개의 수치값에 대한 관계를 파악

# %%
sns.scatterplot(x='순위', y='댓글수', data=df)
plt.title("순위와 댓글 관계")
plt.show()

# %% [markdown]
# ## pairplot
# + 데이터프레임을 인수로 받아 그리드(grid) 형태로 각 데이터 열의 조합에 대해 scatter plot

# %%
sns.pairplot(df) 
plt.show()

# %%
sns.pairplot(df, hue='감성') 
plt.show()

# %% [markdown]
# &#9997; **pandas 노트**
#
#
# ---
# + **피벗테이블**
#   + 피봇테이블(pivot table): 데이터 열 중에서 두 개의 열을 각각 행 인덱스, 열 인덱스로 사용하여 데이터를 조회하여 펼쳐놓은 것
#   + pivot(행 인덱스로 사용할 열 이름, 열 인덱스로 사용할 열 이름, 데이터로 사용할 열 이름)
#     + **행인덱스와 열인덱스로 데이터가 단 하나만 찾아져야 함**
#
# + **groupby**
#   + **키가 지정하는 조건에 맞는 데이터가 하나 이상이라서 데이터 그룹을 이루는 경우**
#   + groupby(그룹할 열인덱스).연산함수()
#     + size, count: 그룹 데이터의 갯수
#     + mean, median, min, max: 그룹 데이터의 평균, 중앙값, 최소, 최대
#     + sum, prod, std, var, quantile : 그룹 데이터의 합계, 곱, 표준편차, 분산, 사분위수
#
# + **상관관계**
#   + corr() : 각 변수간의 상관계수 출력

# %% [markdown]
# ## heatmap
# + 데이터가 2차원이고 모든 값이 카테고리 값

# %%
dfg = df.groupby(['언론사','감성'])[['순위']].count()
dfg = dfg.reset_index() 
dfg
# Out:
#        언론사  감성  순위
# 0     JTBC  긍정   1
# 1     JTBC  부정   4
# 2      KBS  부정   2
# 3      MBC  부정   6
# 4      MBN  부정   1
# 5      SBS  부정   2
# 6      YTN  부정   1
# 7     국민일보  부정   1
# 8     노컷뉴스  중립   1
# 9      뉴스1  부정   2
# 10     뉴시스  부정   1
# 11    동아일보  부정   1
# 12    매일경제  긍정   2
# 13    문화일보  부정   1
# 14    서울신문  부정   3
# 15    세계일보  긍정   1
# 16    세계일보  부정   2
# 17   아시아경제  부정   2
# 18    연합뉴스  부정   2
# 19   오마이뉴스  부정   2
# 20    이데일리  부정   2
# 21    이데일리  중립   1
# 22    조선비즈  부정   1
# 23    중앙일보  부정   2
# 24    쿠키뉴스  부정   1
# 25     한겨레  부정   2
# 26  한국경제TV  부정   1
# 27    한국일보  긍정   1
# 28   헤럴드경제  부정   1

# %%
dfgv = dfg.pivot('언론사', '감성', '순위')
dfgv
# Out:
# 감성      긍정  부정  중립
# 언론사
# JTBC     1   4 nan
# KBS    nan   2 nan
# MBC    nan   6 nan
# MBN    nan   1 nan
# SBS    nan   2 nan
# YTN    nan   1 nan
# 국민일보   nan   1 nan
# 노컷뉴스   nan nan   1
# 뉴스1    nan   2 nan
# 뉴시스    nan   1 nan
# 동아일보   nan   1 nan
# 매일경제     2 nan nan
# 문화일보   nan   1 nan
# 서울신문   nan   3 nan
# 세계일보     1   2 nan
# 아시아경제  nan   2 nan
# 연합뉴스   nan   2 nan
# 오마이뉴스  nan   2 nan
# 이데일리   nan   2   1
# 조선비즈   nan   1 nan
# 중앙일보   nan   2 nan
# 쿠키뉴스   nan   1 nan
# 한겨레    nan   2 nan
# 한국경제TV nan   1 nan
# 한국일보     1 nan nan
# 헤럴드경제  nan   1 nan

# %%
sns.heatmap(dfgv, annot=True)
plt.show()

# %%
sns.heatmap(dfgv.isnull())
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## 해결문제
# ---
# 대학 알리미 사이트에서 대학등록금 현황 자료를 받아서 다음 그림을 그리시오.
# + 지역별 설립구분별 학교수
# + 지역별 등록금 평균
# + 평균등록금 보다 많이 내는 학교수를 지역별 카운트 그래프
#
# + [대학알리미] : https://www.academyinfo.go.kr/search/search.do

# %%
 
df.head()
# Out:
#    기준연도 학교종류 설립구분   지역   상태  ...    인문사회    자연과학     예체능      공학      의학
# 0   nan  NaN  NaN  NaN  NaN  ...     nan     nan     nan     nan     nan
# 1  2021  대학교   사립   경남   기존  ... 5849684 7206557       0       0       0
# 2  2021  대학교   사립   경기   기존  ... 7098467 8283510 9177056 9076000 9890000
# 3  2021  대학교   사립   강원   기존  ... 6157423 7459345 8218087 8135563 9850000
# 4  2021  대학교   사립   충북   기존  ... 6618000 7796000       0       0       0
#
# [5 rows x 14 columns]

# %%
 
df.head()
# Out:
#    기준연도 학교종류 설립구분  지역  상태  ...    인문사회    자연과학     예체능      공학      의학
# 1  2021  대학교   사립  경남  기존  ... 5849684 7206557       0       0       0
# 2  2021  대학교   사립  경기  기존  ... 7098467 8283510 9177056 9076000 9890000
# 3  2021  대학교   사립  강원  기존  ... 6157423 7459345 8218087 8135563 9850000
# 4  2021  대학교   사립  충북  기존  ... 6618000 7796000       0       0       0
# 5  2021  대학교   사립  경기  기존  ... 6122000 7454337 8562000 8284000       0
#
# [5 rows x 14 columns]

# %%
 
df
# Out:
#           학교종류 설립구분  지역  상태  ...    자연과학     예체능      공학      의학
# 1          대학교   사립  경남  기존  ... 7206557       0       0       0
# 2          대학교   사립  경기  기존  ... 8283510 9177056 9076000 9890000
# 3          대학교   사립  강원  기존  ... 7459345 8218087 8135563 9850000
# 4          대학교   사립  충북  기존  ... 7796000       0       0       0
# 5          대학교   사립  경기  기존  ... 7454337 8562000 8284000       0
# ..         ...  ...  ..  ..  ...     ...     ...     ...     ...
# 240        대학교   사립  충남  기존  ... 7733013 8219725 8264385       0
# 241       산업대학   사립  전북  기존  ... 7148930 7484849 6999746       0
# 242        대학교   사립  서울  기존  ... 6848000 9070658 8810862       0
# 243        대학교   사립  세종  기존  ...       0 8984000 8799536       0
# 244  사이버대학(대학)   사립  부산  기존  ...       0       0       0       0
#
# [244 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 1 to 244
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학교종류    244 non-null    object
#  1   설립구분    244 non-null    object
#  2   지역      244 non-null    object
#  3   상태      244 non-null    object
#  4   학교      244 non-null    object
#  5   입학금     244 non-null    float64
#  6   수업료     244 non-null    float64
#  7   등록금     244 non-null    float64
#  8   인문사회    244 non-null    float64
#  9   자연과학    244 non-null    float64
#  10  예체능     244 non-null    float64
#  11  공학      244 non-null    float64
#  12  의학      244 non-null    float64
# dtypes: float64(8), object(5)
# memory usage: 26.7+ KB

# %%
df.columns = ['학교종류', '설립구분', '지역', '상태', '학교', '입학금 ', '수업료 ', '등록금', '인문사회',
       '자연과학', '예체능', '공학', '의학']

df.columns
# Out:
# Index(['학교종류', '설립구분', '지역', '상태', '학교', '입학금 ', '수업료 ', '등록금', '인문사회', '자연과학',
#        '예체능', '공학', '의학'],
#       dtype='object')

# %% [markdown]
# * 지역별 설립구분별 학교수

# %%
plt.figure(figsize=(10,7))
 
plt.show()

# %% [markdown]
# + 지역별 등록금 평균

# %%
plt.figure(figsize=(10,7))
 
plt.show()

# %%
plt.figure(figsize=(10,7))
 
plt.show()

# %% [markdown]
# + 평균등록금 보다 많이 내는 학교수를 지역별 카운트 그래프

# %%
plt.figure(figsize=(10,7))
 
plt.show()
